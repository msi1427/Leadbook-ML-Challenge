# %%
# !nvidia-smi
# Out:
# Tue Nov 23 04:22:45 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/msi1427/Leadbook-ML-Challenge.git
# %cd Leadbook-ML-Challenge
# Out:
# Cloning into 'Leadbook-ML-Challenge'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 115 (delta 37), reused 96 (delta 18), pack-reused 0
# Receiving objects: 100% (115/115), 83.52 MiB | 26.76 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# /content/Leadbook-ML-Challenge

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 97 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 97 kB 9.0 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 59 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 61 kB 10.5 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 66.3 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 59.7 MB/s
# ...
#      |████████████████████████████████| 11.3 MB 64.5 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 55.7 MB/s
# ...
#      |████████████████████████████████| 503 kB 68.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 65.0 MB/s
# ...
#      |████████████████████████████████| 749 kB 30.5 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 35.8 MB/s
# ...
#      |████████████████████████████████| 38.2 MB 1.3 MB/s
# ...

# %%
! python scripts/data_prep.py --raw_dept_data departments.json
# Out:
# Data Preparation Complete

# %%
! python scripts/train.py --train_data train.csv --gpu 0
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration:  71% 4539/6368 [04:02<03:16,  9.29it/s]
# Iteration:  71% 4542/6368 [04:02<03:10,  9.59it/s]
# Iteration:  71% 4545/6368 [04:02<03:03,  9.93it/s]
# Iteration:  71% 4548/6368 [04:02<02:57, 10.26it/s]
# Iteration:  71% 4551/6368 [04:02<02:52, 10.53it/s]
# Iteration:  72% 4555/6368 [04:02<02:45, 10.99it/s]
# Iteration:  72% 4558/6368 [04:02<02:39, 11.33it/s]
# Iteration:  72% 4562/6368 [04:02<02:33, 11.80it/s]
# Iteration:  72% 4565/6368 [04:03<02:28, 12.11it/s]
# Iteration:  72% 4568/6368 [04:03<02:24, 12.45it/s]
# Iteration:  72% 4571/6368 [04:03<02:20, 12.76it/s]
# Iteration:  72% 4574/6368 [04:03<02:17, 13.06it/s]
# Iteration:  72% 4577/6368 [04:03<02:13, 13.40it/s]
# Iteration:  72% 4580/6368 [04:03<02:10, 13.67it/s]
# Iteration:  72% 4583/6368 [04:03<02:07, 14.01it/s]
# Iteration:  72% 4586/6368 [04:03<02:04, 14.35it/s]
# Iteration:  72% 4589/6368 [04:04<02:01, 14.64it/s]
# ...

# %%
! python scripts/inference.py --test_data jobtitles_all.txt --dept_data departments_processed.json --gpu 0 --trained_model bert-base-nli-mean-tokens
# Out:
# Retrieving folder list
# Retrieving folder 13WFhtWJmu6cghkdLqAWBz12eNx8yJSqA 1_Pooling
# Processing file 13nhxAcDFJhhIFcwPkAbBp8qiytdyVK0E config.json
# Retrieving folder 12tOVpQhSey8T3r9H_S7tcUp_WuMRTHF- eval
# Processing file 136MOPPvOgsU89KtEbV8UomEqhn63c2Rh similarity_evaluation_results.csv
# Processing file 13CVbyq1q6WNXKFZsGkygwvWmel4fMe15 config_sentence_transformers.json
# Processing file 138dGeSKeQdsFPUgX5wRT6w3aPIXC_6vQ config.json
# Processing file 13Ox_WYET-uHZzjRd6NU0k-dQ-SYlb0Vt modules.json
# Processing file 13GhzMmxx6nbP0fKUDxztx3ZJY1LiAOlU pytorch_model.bin
# Processing file 13OHpv4j6ShRijmuOjyiylqYg7Twx1s9L README.md
# Processing file 13XF_27KyutZQQ8cWcJ2_zfFSUlrJ5-yQ sentence_bert_config.json
# Processing file 13mGgCLqVh8dLeUtmd_VTieNTE_l2ktvW special_tokens_map.json
# Processing file 13nHvAMV--QAPC1OWLsz3Iz57rwNgSpGI tokenizer_config.json
# Processing file 13ccq3sNKABc_c3iX8zX8_Lc5bhssEjIg tokenizer.json
# ...
